# %% [markdown]
# <a href="https://colab.research.google.com/github/NEEEEEEEEEEEL/Debnil/blob/main/news_calssifcation_using_word_vector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("Fake_Real_Data.csv")
df.head()
# Out:
#                                                 Text label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake
# 1  U.S. conservative leader optimistic of common ...  Real
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake
# 4  Democrats say Trump agrees to work on immigrat...  Real

# %%
df["new_label"]=df["label"].map({"Fake":0,"Real":1})

# %%
df.head()
# Out:
#                                                 Text label  new_label
# 0   Top Trump Surrogate BRUTALLY Stabs Him In The...  Fake          0
# 1  U.S. conservative leader optimistic of common ...  Real          1
# 2  Trump proposes U.S. tax overhaul, stirs concer...  Real          1
# 3   Court Forces Ohio To Allow Millions Of Illega...  Fake          0
# 4  Democrats say Trump agrees to work on immigrat...  Real          1

# %%
import spacy
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.4.0/en_core_web_lg-3.4.0.tar.gz
nlp=spacy.load("en_core_web_lg")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
doc=nlp("top trump is whatever")
doc.vector.shape
# Out:
# (300,)

# %%
df["vector"]=df['Text'].apply(lambda x:nlp(x).vector)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df.vector,df.new_label,test_size=0.2)

# %% [markdown]
# but we cant train the model because we need to transform the data

# %%
import numpy as np
x_train_2d=np.stack(x_train)
x_test_2d=np(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaScaler()
scaled_embeded_train=scaler.fit_transform(x_train_2d)
scaled_embeded_test=scaler.transform(x_test_2d)

# %%
clf=MultinomialNB()
clf.fit(scaled_embeded_train,y_train)
